# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cancertype = "Larynx"
pollution = "CO"
state = "IL"

# %%
cancer_new = pd.read_csv("../Data/Data_for_Graphing/ARcancer.csv")
cancer_old = pd.read_csv("../Data/cancer.csv")
pollution_new = pd.read_csv("../Data/Data_for_Graphing/ARpollution.csv")
pollution_old = pd.read_csv("../Data/pollution.csv")

# %%
cancer_new_clean = cancer_new.drop('Unnamed: 0', axis =1)
cancer_new_clean = cancer_new_clean.replace("NaN", 0)

cancer_new_clean
# Out:
#       Cancer  Gender    Larynx       Lung  Nasal                       Race  \
# 0     Larynx    Male  8.100000        NaN    NaN  Black or African American
# 1     Larynx    Male  8.500000        NaN    NaN  Black or African American
# 2     Larynx    Male  8.400000        NaN    NaN  Black or African American
# 3     Larynx    Male  7.700000        NaN    NaN  Black or African American
# 4     Larynx    Male  6.100000        NaN    NaN  Black or African American
# 5     Larynx    Male  7.600000        NaN    NaN  Black or African American
# 6     Larynx    Male  6.700000        NaN    NaN  Black or African American
# 7     Larynx    Male  7.200000        NaN    NaN  Black or African American
# 8     Larynx    Male  7.500000        NaN    NaN  Black or African American
# 9     Larynx    Male  6.500000        NaN    NaN  Black or African American
# 10    Larynx    Male  6.700000        NaN    NaN  Black or African American
# 11    Larynx    Male  5.900000        NaN    NaN  Black or African American
# 12    Larynx    Male  5.000000        NaN    NaN  Black or African American
# 13    Larynx    Male  4.100000        NaN    NaN  Black or African American
# 14    Larynx    Male  6.500000        NaN    NaN  Black or African American
# 15    Larynx    Male  4.400000        NaN    NaN  Black or African American
# 16    Larynx    Male  4.500000        NaN    NaN  Black or African American
# 17    Larynx    Male  4.869660        NaN    NaN  Black or African American
# 18    Larynx    Male  3.110416        NaN    NaN  Black or African American
# 19    Larynx    Male  2.073887        NaN    NaN  Black or African American
# 20    Larynx    Male  2.489219        NaN    NaN  Black or African American
# 21    Larynx    Male  2.127098        NaN    NaN  Black or African American
# 22    Larynx    Male  1.632230        NaN    NaN  Black or African American
# 23    Larynx    Male  0.158759        NaN    NaN  Black or African American
# 24    Larynx    Male  0.305043        NaN    NaN  Black or African American
# 25    Larynx    Male  0.000000        NaN    NaN  Black or African American
# 26    Larynx    Male  0.095624        NaN    NaN  Black or African American
# 27      Lung    Male       NaN  73.200000    NaN                      White
# 28      Lung    Male       NaN  72.000000    NaN                      White
# 29      Lung    Male       NaN  68.000000    NaN                      White
# ...      ...     ...       ...        ...    ...                        ...
# 6774    Lung  Female       NaN   4.266696    NaN                      White
# 6775    Lung  Female       NaN   7.381723    NaN                      White
# 6776    Lung  Female       NaN   7.603162    NaN                      White
# 6777    Lung  Female       NaN  43.900000    NaN  Black or African American
# 6778    Lung  Female       NaN  40.900000    NaN  Black or African American
# 6779    Lung  Female       NaN  41.200000    NaN  Black or African American
# 6780    Lung  Female       NaN  39.500000    NaN  Black or African American
# 6781    Lung  Female       NaN  46.100000    NaN  Black or African American
# 6782    Lung  Female       NaN  47.400000    NaN  Black or African American
# 6783    Lung  Female       NaN  47.400000    NaN  Black or African American
# 6784    Lung  Female       NaN  46.300000    NaN  Black or African American
# 6785    Lung  Female       NaN  45.000000    NaN  Black or African American
# 6786    Lung  Female       NaN  42.000000    NaN  Black or African American
# 6787    Lung  Female       NaN  47.500000    NaN  Black or African American
# 6788    Lung  Female       NaN  48.000000    NaN  Black or African American
# 6789    Lung  Female       NaN  43.100000    NaN  Black or African American
# 6790    Lung  Female       NaN  43.100000    NaN  Black or African American
# 6791    Lung  Female       NaN  43.400000    NaN  Black or African American
# 6792    Lung  Female       NaN  47.100000    NaN  Black or African American
# 6793    Lung  Female       NaN  44.700000    NaN  Black or African American
# 6794    Lung  Female       NaN  44.974226    NaN  Black or African American
# 6795    Lung  Female       NaN  22.503325    NaN  Black or African American
# 6796    Lung  Female       NaN  33.229496    NaN  Black or African American
# 6797    Lung  Female       NaN  26.603196    NaN  Black or African American
# 6798    Lung  Female       NaN  19.170342    NaN  Black or African American
# 6799    Lung  Female       NaN  15.500118    NaN  Black or African American
# 6800    Lung  Female       NaN  10.363283    NaN  Black or African American
# 6801    Lung  Female       NaN   7.845018    NaN  Black or African American
# 6802    Lung  Female       NaN   8.645896    NaN  Black or African American
# 6803    Lung  Female       NaN   5.637748    NaN  Black or African American
#
#      State  Trachea  Year
# 0       NJ      NaN  1999
# 1       NJ      NaN  2000
# 2       NJ      NaN  2001
# 3       NJ      NaN  2002
# 4       NJ      NaN  2003
# 5       NJ      NaN  2004
# 6       NJ      NaN  2005
# 7       NJ      NaN  2006
# 8       NJ      NaN  2007
# 9       NJ      NaN  2008
# 10      NJ      NaN  2009
# 11      NJ      NaN  2010
# 12      NJ      NaN  2011
# 13      NJ      NaN  2012
# 14      NJ      NaN  2013
# 15      NJ      NaN  2014
# 16      NJ      NaN  2015
# 17      NJ      NaN  2016
# 18      NJ      NaN  2017
# 19      NJ      NaN  2018
# 20      NJ      NaN  2019
# 21      NJ      NaN  2020
# 22      NJ      NaN  2021
# 23      NJ      NaN  2022
# 24      NJ      NaN  2023
# 25      NJ      NaN  2024
# 26      NJ      NaN  2025
# 27      VA      NaN  1999
# 28      VA      NaN  2000
# 29      VA      NaN  2001
# ...    ...      ...   ...
# 6774    IA      NaN  2023
# 6775    IA      NaN  2024
# 6776    IA      NaN  2025
# 6777    CA      NaN  1999
# 6778    CA      NaN  2000
# 6779    CA      NaN  2001
# 6780    CA      NaN  2002
# 6781    CA      NaN  2003
# 6782    CA      NaN  2004
# 6783    CA      NaN  2005
# 6784    CA      NaN  2006
# 6785    CA      NaN  2007
# 6786    CA      NaN  2008
# 6787    CA      NaN  2009
# 6788    CA      NaN  2010
# 6789    CA      NaN  2011
# 6790    CA      NaN  2012
# 6791    CA      NaN  2013
# 6792    CA      NaN  2014
# 6793    CA      NaN  2015
# 6794    CA      NaN  2016
# 6795    CA      NaN  2017
# 6796    CA      NaN  2018
# 6797    CA      NaN  2019
# 6798    CA      NaN  2020
# 6799    CA      NaN  2021
# 6800    CA      NaN  2022
# 6801    CA      NaN  2023
# 6802    CA      NaN  2024
# 6803    CA      NaN  2025
#
# [6804 rows x 9 columns]

# %%
cancer_old_clean = cancer_old.drop(['Unnamed: 0', "States Code", "Year Code", "Race Code", "Cancer Sites Code", 'Count', "Population"], axis=1)
cancer_old_clean=cancer_old_clean.replace("Lung and Bronchus", "Lung")
cancer_old_clean=cancer_old_clean.replace("Nose, Nasal Cavity and Middle Ear", "Nasal")
cancer_old_clean=cancer_old_clean.replace("Trachea, Mediastinum and Other Respiratory Organs", "Trachea")
cancer_old_clean = cancer_old_clean.replace("Not applicable", 0)
cancer_old_clean["Crude Rate"] = pd.to_numeric(cancer_old_clean["Crude Rate"], errors='coerce')

cancer_old_clean
# Out:
#      State  Year     Sex Sex Code                              Race  \
# 0       AL  1999  Female        F         Black or African American
# 1       AL  1999  Female        F                             White
# 2       AL  1999  Female        F                             White
# 3       AL  1999    Male        M         Black or African American
# 4       AL  1999    Male        M         Black or African American
# 5       AL  1999    Male        M                             White
# 6       AL  1999    Male        M                             White
# 7       AL  1999    Male        M                             White
# 8       AK  1999  Female        F                             White
# 9       AK  1999    Male        M  American Indian or Alaska Native
# 10      AK  1999    Male        M                             White
# 11      AZ  1999  Female        F         Black or African American
# 12      AZ  1999  Female        F                             White
# 13      AZ  1999  Female        F                             White
# 14      AZ  1999    Male        M         Black or African American
# 15      AZ  1999    Male        M                             White
# 16      AZ  1999    Male        M                             White
# 17      CA  1999  Female        F  American Indian or Alaska Native
# 18      CA  1999  Female        F         Asian or Pacific Islander
# 19      CA  1999  Female        F         Black or African American
# 20      CA  1999  Female        F         Black or African American
# 21      CA  1999  Female        F                             White
# 22      CA  1999  Female        F                             White
# 23      CA  1999  Female        F                             White
# 24      CA  1999    Male        M  American Indian or Alaska Native
# 25      CA  1999    Male        M         Asian or Pacific Islander
# 26      CA  1999    Male        M         Asian or Pacific Islander
# 27      CA  1999    Male        M         Black or African American
# 28      CA  1999    Male        M         Black or African American
# 29      CA  1999    Male        M                             White
# ...    ...   ...     ...      ...                               ...
# 6866    WA  2015  Female        F         Asian or Pacific Islander
# 6867    WA  2015  Female        F         Black or African American
# 6868    WA  2015  Female        F                             White
# 6869    WA  2015  Female        F                             White
# 6870    WA  2015  Female        F                             White
# 6871    WA  2015    Male        M  American Indian or Alaska Native
# 6872    WA  2015    Male        M         Asian or Pacific Islander
# 6873    WA  2015    Male        M         Black or African American
# 6874    WA  2015    Male        M                             White
# 6875    WA  2015    Male        M                             White
# 6876    WA  2015    Male        M                             White
# 6877    WA  2015    Male        M  Other Races and Unknown combined
# 6878    WV  2015  Female        F                             White
# 6879    WV  2015  Female        F                             White
# 6880    WV  2015    Male        M         Black or African American
# 6881    WV  2015    Male        M                             White
# 6882    WV  2015    Male        M                             White
# 6883    WI  2015  Female        F  American Indian or Alaska Native
# 6884    WI  2015  Female        F         Asian or Pacific Islander
# 6885    WI  2015  Female        F         Black or African American
# 6886    WI  2015  Female        F                             White
# 6887    WI  2015  Female        F                             White
# 6888    WI  2015    Male        M         Asian or Pacific Islander
# 6889    WI  2015    Male        M         Black or African American
# 6890    WI  2015    Male        M         Black or African American
# 6891    WI  2015    Male        M                             White
# 6892    WI  2015    Male        M                             White
# 6893    WI  2015    Male        M                             White
# 6894    WY  2015  Female        F                             White
# 6895    WY  2015    Male        M                             White
#
#      Cancer Sites  Crude Rate
# 0            Lung        29.4
# 1          Larynx         2.1
# 2            Lung        61.3
# 3          Larynx         7.2
# 4            Lung        75.5
# 5           Nasal         1.3
# 6          Larynx         8.8
# 7            Lung       110.3
# 8            Lung        49.1
# 9            Lung        47.1
# 10           Lung        47.5
# 11           Lung        22.4
# 12         Larynx         1.7
# 13           Lung        56.1
# 14           Lung        55.0
# 15         Larynx         5.8
# 16           Lung        75.1
# 17           Lung        12.4
# 18           Lung        20.6
# 19         Larynx         1.7
# 20           Lung        43.9
# 21          Nasal         0.5
# 22         Larynx         1.3
# 23           Lung        53.9
# 24           Lung         7.0
# 25         Larynx         2.1
# 26           Lung        38.2
# 27         Larynx         7.7
# 28           Lung        61.5
# 29          Nasal         0.6
# ...           ...         ...
# 6866         Lung        26.1
# 6867         Lung        28.8
# 6868        Nasal         0.6
# 6869       Larynx         0.9
# 6870         Lung        64.9
# 6871         Lung        32.9
# 6872         Lung        33.3
# 6873         Lung        32.6
# 6874        Nasal         1.0
# 6875       Larynx         4.8
# 6876         Lung        66.6
# 6877         Lung         NaN
# 6878       Larynx         3.1
# 6879         Lung        97.4
# 6880         Lung        54.5
# 6881       Larynx        11.1
# 6882         Lung       128.7
# 6883         Lung        46.7
# 6884         Lung        21.8
# 6885         Lung        47.0
# 6886       Larynx         1.9
# 6887         Lung        69.9
# 6888         Lung        25.4
# 6889       Larynx         8.8
# 6890         Lung        65.5
# 6891        Nasal         1.1
# 6892       Larynx         6.5
# 6893         Lung        79.3
# 6894         Lung        51.4
# 6895         Lung        46.2
#
# [6896 rows x 7 columns]

# %%
pollution_new_clean= pollution_new.drop('Unnamed: 0', axis =1)

# %%
pollution_old_clean = pollution_old.drop(['Unnamed: 0', 'County Code'], axis =1)

# %%
years_old = cancer_old_clean["Year"].unique()
years_new = cancer_new_clean["Year"].unique()

# %%
cancer_old_rates = []
for year in years_old:
    rate = cancer_old_clean.loc[(cancer_old_clean["Cancer Sites"]==cancertype) & (cancer_old_clean["State"]==state)&(cancer_old_clean["Year"]==year)]["Crude Rate"].sum()
                                                                                                                                                
    cancer_old_rates.append(rate)

# %%
cancer_new_rates = []
for year in years_new:
    rate = cancer_new_clean.loc[(cancer_new_clean["Cancer"]==cancertype)&(cancer_new_clean["State"]==state)&(cancer_new_clean["Year"]==year)][cancertype].sum() 
    cancer_new_rates.append(rate)

# %%
poll_old = pollution_old_clean.loc[(pollution_old_clean["State"]==state)][pollution]
poll_new = pollution_new_clean.loc[(pollution_new_clean["State"]==state)][pollution]

# %%
old_corr = pd.DataFrame({"Year":years_old, pollution: poll_old, "Cancer Rates": cancer_old_rates})

# %%
len(cancer_new_rates)
# Out:
# 27

# %%
new_corr = pd.DataFrame({"Year":years_new, pollution: poll_new, "Cancer Rates": cancer_new_rates})

# %%
old_corr.plot.scatter(x=pollution, y="Cancer Rates")
plt.show()

# %%
new_corr.plot.scatter(x=pollution, y="Cancer Rates")
plt.show()

# %%
old_df = pd.DataFrame(old_corr[[pollution, "Cancer Rates"]])
new_df = pd.DataFrame(old_corr[[pollution, "Cancer Rates"]])

# %%
old_df.corr(method = "pearson")
old_df.corr(method = "kendall")
old_df.corr(method = "spearman")
# Out:
#                     CO  Cancer Rates
# CO            1.000000      0.590184
# Cancer Rates  0.590184      1.000000

# %%
new_df.corr(method = "pearson")
new_df.corr(method = "kendall")
new_df.corr(method = "spearman")
# Out:
#                     CO  Cancer Rates
# CO            1.000000      0.590184
# Cancer Rates  0.590184      1.000000
